# %% [markdown]
# # Fitted Q-learning algo

# %% [markdown]
# Below is a version of the fitted Q-Learning algorithm described [last time]((https://www.dropbox.com/s/3qjqhpo1mix0w9h/deep_QLearning_part_2_SLIDES.pdf?dl=0).  Recall the main variation here is just this: instead of updating $Q$ *inside* each episode, we wait (at least) until the end of the episode to update.
#
# A few quirks of this implementation:
# - its written in Keras-Tensorflow
# - The size of memory for memory replay is fixed at a number of episodes instead of a number of steps.
# - There are a large number of user-controls - defined in the initialization - that allow for a wide range of use, including parameters to control how often the weights of $Q$ are saved, how often $Q$ is updated (in terms of number of episodes),...

# %%
import numpy as np
import copy
import os
import pickle
from keras.layers import Dense, Flatten, Conv2D, Lambda, MaxPooling2D
from keras.optimizers import RMSprop
from keras.models import Sequential
#from keras.applications.mobilenet import MobileNet
#from keras.applications.mobilenet_v2 import MobileNetV2
from keras.preprocessing.image import img_to_array
#import gym
import retro
import cv2
#from shufflenetv2 import ShuffleNetV2
import gc

def multiplyList(myList) : 
      
    # Multiply elements one by one 
    result = 1
    for x in myList: 
         result = result * x  
    return result  

def toBinAction(my_int):
    my_str = "{:08b}".format(my_int)
    return np.array([int(ii) for ii in my_str], dtype=np.int8)

def resizeImage(image):
    xx, yy, _ = image.shape
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (xx//5, yy//5))
    gray = gray.astype(np.float) / 255.
    gray = img_to_array(gray)
    return gray

def resizeImageMultiple(images):
    grays = []
    for image in images:
        grays.append(resizeImage(image))
    return np.array(grays)

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,gymname,dirname,savename,**kwargs):
        # load in gym simulator
        self.simulator = retro.make(gymname) 
             
        # Q learn basic params
        self.explore_val = 1       # how often should an action be chosen randomly vs using the optimal control law, larger values mean actions are more often chosen randomly
        self.explore_decay = 0.99  # after each episode the explore_val is multiplied by explore_decay to (potentially) shrink it
        self.gamma = 1             # short-term/long-term trade-off param
        self.num_episodes = 500    # number of episodes of simulation to perform
        self.save_weight_freq = 10 # controls how often (in number of episodes) the weights of $Q$ are saved 
        self.memory = []           # memory container
        
        # fitted Q-Learning params
        self.episode_update = 1     # after how many episodes should we update Q?
        self.memory_length = 10     # length of memory replay (in episodes)

        # simulation-specific params
        self.exit_level = 200       # sets the optimal episode reward required for 'success'
        self.exit_window = 100      # sets the window over which average total reward per episode must be >= exit_level  to deem Q resolved successfully
        
        # new parameters
        self.delay_step = 4
        # let user define each of the params above
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
        if 'exit_level' in kwargs:
            self.exit_level = kwargs['exit_level']
        if 'exit_window' in kwargs:
            self.exit_window = kwargs['exit_window']  
        if 'save_weight_freq' in kwargs:
            self.save_weight_freq = kwargs['save_weight_freq']
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
        if 'delay_step' in kwargs:
            self.delay_step = kwargs['delay_step']
            
        # get simulation-specific variables from simulator
        self.num_actions = 2 ** self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.shape(resizeImage(state))
        self.training_reward = []
        
        ### initialize logs ###
        # create text file for training log
        self.logname = dirname + '/training_logs/' + savename + '.txt'
        self.reward_logname = dirname + '/reward_logs/' + savename + '.txt'
        self.weight_name = dirname + '/saved_model_weights/' + savename + '.pkl' 
        self.model_name = dirname + '/models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        lr = 10**(-2)
        if 'alpha' in kwargs:
            lr = kwargs['alpha']
        optimizer = RMSprop(lr = lr)        

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions

        # build model based on parameters
        self.model = Sequential()

        # add input layer
        #self.model.add(MobileNetV2(input_shape=input_dim, include_top=True, weights=None))
        #self.model.add(ShuffleNetV2(input_shape=input_dim, include_top=True, scale_factor=0.5))
        self.model.add(Conv2D(32, (8,8), strides=4, activation=activation, input_shape=input_dim))
        self.model.add(Conv2D(64, (4,4), strides=2, activation=activation))
        #self.model.add(Conv2D(32, (2,3), strides=1, activation=activation))
        self.model.add(Flatten())
        self.model.add(Dense(512, activation=activation))
        #self.model.add(ShuffleNetV2(input_shape=input_dim, include_top=True, scale_factor=0.5))
        #self.model.add(Flatten())
        #self.model.add(Dense(layer_sizes[0], activation=activation))

        # add hidden layers
        #for U in layer_sizes[1:]:
        #    self.model.add(Dense(U,activation=activation))

        # add output layer
        self.model.add(Dense(output_dim, activation='linear'))

        # chose optimizer and its associated parameters
        self.model.compile(loss=loss, optimizer=optimizer)
        
        # initialize Q
        self.Q = self.model.predict
        
        # since its easy to save models with keras / tensorflow, save to file
        model_json = self.model.to_json()
        with open(self.model_name, "w") as json_file:
            json_file.write(model_json)

    # update Q function
    def update_Q(self):        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(resizeImageMultiple(next_state))
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(resizeImageMultiple(state)).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
        s_in_t = s_in.transpose([3,0,1,2])
        s_in_t = resizeImageMultiple(s_in_t)
        
        print(s_in_t.shape, q_vals.T.shape)
        
        # take descent step
        num_pts = s_in.shape[1]
        self.model.fit(x=s_in_t,y=q_vals.T,batch_size=num_pts, epochs=1,verbose = 0)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
        action = toBinAction(action)
            
        # pick action based on exploiting
        #print('259', state.shape)
        qs = self.Q(resizeImageMultiple(state)) 
        #if p > self.explore_val:
        #    action = np.argmax(qs)
        #    action = toBinAction(action)
        #    print('C')
        #else:
        #    print('R')
        return action
    
    # main training function
    def train(self,**kwargs):             
        gc.collect()
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            episode_data = []
            while done == False:
                # choose next action
                action = self.choose_action(state)
                
                for _ in range(self.delay_step):
    
                    current_state = copy.deepcopy(state)
                    # transition to next state, get associated reward
                    next_state,reward,done,info = self.simulator.step(action)  
                    next_state = self.state_normalizer(next_state)

                    # store data for transition after episode ends
                    
                    # update total reward from this episode
                    total_episode_reward+=reward
                    state = copy.deepcopy(next_state)
                    
                episode_data.append([current_state,next_state,action,reward,done])

            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            # update episode reward greater than exit_level, add to counter
            exit_ave = total_episode_reward
            if n >= self.exit_window:
                exit_ave = np.sum(np.array(self.training_reward[-self.exit_window:]))/self.exit_window

            ### print out updates ###
            update = 'episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,1)) + ', ave reward = ' + str(np.round(exit_ave,1))
                              
            print (update)
            self.update_log(self.logname,update + '\n')
                              
            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            if np.mod(n,self.save_weight_freq) == 0:
                update = self.model.get_weights()
                self.update_log(self.weight_name,update)
            
            # if the total episode reward is greater than exit level for 10 consecutive episodes, break
            if exit_ave >= self.exit_level and n >= self.exit_window:
                break
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Episode reward history plotter

# %%
import matplotlib.pyplot as plt
import numpy as np

# moving average function
def moving_average(x,D):
    y = []
    for p in range(len(x)+1):
        # make next element
        b = np.sum(x[np.maximum(0,p-D):p])/float(D)
        y.append(b)
    return np.array(y)

def plot_reward_history(logname,**kwargs):
    start = 1
    window_length = 5
    if 'window_length' in kwargs:
        window_length = kwargs['window_length']
    if 'start' in kwargs:
        start = kwargs['start']
        
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = moving_average(data,window_length)

    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    ax1.plot(data)
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ave[:window_length] = np.nan
    ax2.plot(ave,linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %% [markdown]
# # Run fitted Q-Learning algo

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'qfitted_qbert_experiment_1'
gymname = 'CartPole-v1'
gymname = 'Qbert-Atari2600'

# initialize Q Learn process
num_episodes = 100000
explore_decay = 0.999
explore_val = 1
exit_level = 10000
exit_window = 100
save_weight_freq = 1000
delay_step=2
# initialize memory
episode_update = 1
memory_length = 1

# load into instance of learner
try:
    demo.simulator.close()
except:
    True

demo = QLearner(gymname,dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,\
                memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window,\
                save_weight_freq=save_weight_freq,delay_step=delay_step)

# initialize Q function
layer_sizes = []
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARNING:tensorflow:From C:\Users\wangc\.conda\envs\gym\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
demo.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 7, 9, 32)          2080
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 3, 64)          32832
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               197120
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# =================================================================
# Total params: 363,360
# Trainable params: 363,360
# Non-trainable params: 0
# _________________________________________________________________

# %%
demo.train()
# Out:
# (757, 32, 42, 1) (757, 256)
# WARNING:tensorflow:From C:\Users\wangc\.conda\envs\gym\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode 1 of 100000 complete,  explore val = 0.999, episode reward = 275.0, ave reward = 275.0
# (658, 32, 42, 1) (658, 256)
# episode 2 of 100000 complete,  explore val = 0.998, episode reward = 175.0, ave reward = 175.0
# (648, 32, 42, 1) (648, 256)
# episode 3 of 100000 complete,  explore val = 0.997, episode reward = 75.0, ave reward = 75.0
# (708, 32, 42, 1) (708, 256)
# episode 4 of 100000 complete,  explore val = 0.996, episode reward = 175.0, ave reward = 175.0
# (632, 32, 42, 1) (632, 256)
# episode 5 of 100000 complete,  explore val = 0.995, episode reward = 75.0, ave reward = 75.0
# (678, 32, 42, 1) (678, 256)
# episode 6 of 100000 complete,  explore val = 0.994, episode reward = 75.0, ave reward = 75.0
# (606, 32, 42, 1) (606, 256)
# episode 7 of 100000 complete,  explore val = 0.993, episode reward = 150.0, ave reward = 150.0
# (583, 32, 42, 1) (583, 256)
# episode 8 of 100000 complete,  explore val = 0.992, episode reward = 200.0, ave reward = 200.0
# (655, 32, 42, 1) (655, 256)
# episode 9 of 100000 complete,  explore val = 0.991, episode reward = 100.0, ave reward = 100.0
# (568, 32, 42, 1) (568, 256)
# episode 10 of 100000 complete,  explore val = 0.99, episode reward = 0.0, ave reward = 0.0
# (700, 32, 42, 1) (700, 256)
# episode 11 of 100000 complete,  explore val = 0.989, episode reward = 425.0, ave reward = 425.0
# (701, 32, 42, 1) (701, 256)
# episode 12 of 100000 complete,  explore val = 0.988, episode reward = 225.0, ave reward = 225.0
# (538, 32, 42, 1) (538, 256)
# episode 13 of 100000 complete,  explore val = 0.987, episode reward = 50.0, ave reward = 50.0
# (630, 32, 42, 1) (630, 256)
# episode 14 of 100000 complete,  explore val = 0.986, episode reward = 150.0, ave reward = 150.0
# (596, 32, 42, 1) (596, 256)
# episode 15 of 100000 complete,  explore val = 0.985, episode reward = 75.0, ave reward = 75.0
# (636, 32, 42, 1) (636, 256)
# episode 16 of 100000 complete,  explore val = 0.984, episode reward = 100.0, ave reward = 100.0
# (538, 32, 42, 1) (538, 256)
# episode 17 of 100000 complete,  explore val = 0.983, episode reward = 50.0, ave reward = 50.0
# (595, 32, 42, 1) (595, 256)
# episode 18 of 100000 complete,  explore val = 0.982, episode reward = 150.0, ave reward = 150.0
# (666, 32, 42, 1) (666, 256)
# episode 19 of 100000 complete,  explore val = 0.981, episode reward = 75.0, ave reward = 75.0
# (962, 32, 42, 1) (962, 256)
# episode 20 of 100000 complete,  explore val = 0.98, episode reward = 200.0, ave reward = 200.0
# (751, 32, 42, 1) (751, 256)
# episode 21 of 100000 complete,  explore val = 0.979, episode reward = 225.0, ave reward = 225.0
# (659, 32, 42, 1) (659, 256)
# episode 22 of 100000 complete,  explore val = 0.978, episode reward = 200.0, ave reward = 200.0
# (674, 32, 42, 1) (674, 256)
# episode 23 of 100000 complete,  explore val = 0.977, episode reward = 250.0, ave reward = 250.0
# (816, 32, 42, 1) (816, 256)
# episode 24 of 100000 complete,  explore val = 0.976, episode reward = 200.0, ave reward = 200.0
# (837, 32, 42, 1) (837, 256)
# episode 25 of 100000 complete,  explore val = 0.975, episode reward = 250.0, ave reward = 250.0
# (663, 32, 42, 1) (663, 256)
# episode 26 of 100000 complete,  explore val = 0.974, episode reward = 150.0, ave reward = 150.0
# (708, 32, 42, 1) (708, 256)
# episode 27 of 100000 complete,  explore val = 0.973, episode reward = 175.0, ave reward = 175.0
# (638, 32, 42, 1) (638, 256)
# episode 28 of 100000 complete,  explore val = 0.972, episode reward = 100.0, ave reward = 100.0
# (713, 32, 42, 1) (713, 256)
# episode 29 of 100000 complete,  explore val = 0.971, episode reward = 150.0, ave reward = 150.0
# (642, 32, 42, 1) (642, 256)
# episode 30 of 100000 complete,  explore val = 0.97, episode reward = 100.0, ave reward = 100.0
# (642, 32, 42, 1) (642, 256)
# episode 31 of 100000 complete,  explore val = 0.969, episode reward = 100.0, ave reward = 100.0
# (788, 32, 42, 1) (788, 256)
# episode 32 of 100000 complete,  explore val = 0.968, episode reward = 125.0, ave reward = 125.0
# (621, 32, 42, 1) (621, 256)
# episode 33 of 100000 complete,  explore val = 0.968, episode reward = 75.0, ave reward = 75.0
# (938, 32, 42, 1) (938, 256)
# episode 34 of 100000 complete,  explore val = 0.967, episode reward = 275.0, ave reward = 275.0
# (848, 32, 42, 1) (848, 256)
# episode 35 of 100000 complete,  explore val = 0.966, episode reward = 225.0, ave reward = 225.0
# (708, 32, 42, 1) (708, 256)
# episode 36 of 100000 complete,  explore val = 0.965, episode reward = 100.0, ave reward = 100.0
# (806, 32, 42, 1) (806, 256)
# episode 37 of 100000 complete,  explore val = 0.964, episode reward = 225.0, ave reward = 225.0
# (633, 32, 42, 1) (633, 256)
# episode 38 of 100000 complete,  explore val = 0.963, episode reward = 125.0, ave reward = 125.0
# (888, 32, 42, 1) (888, 256)
# episode 39 of 100000 complete,  explore val = 0.962, episode reward = 250.0, ave reward = 250.0
# (685, 32, 42, 1) (685, 256)
# episode 40 of 100000 complete,  explore val = 0.961, episode reward = 100.0, ave reward = 100.0
# (646, 32, 42, 1) (646, 256)
# episode 41 of 100000 complete,  explore val = 0.96, episode reward = 175.0, ave reward = 175.0
# (695, 32, 42, 1) (695, 256)
# episode 42 of 100000 complete,  explore val = 0.959, episode reward = 150.0, ave reward = 150.0
# (718, 32, 42, 1) (718, 256)
# episode 43 of 100000 complete,  explore val = 0.958, episode reward = 200.0, ave reward = 200.0
# (586, 32, 42, 1) (586, 256)
# episode 44 of 100000 complete,  explore val = 0.957, episode reward = 25.0, ave reward = 25.0
# (744, 32, 42, 1) (744, 256)
# episode 45 of 100000 complete,  explore val = 0.956, episode reward = 400.0, ave reward = 400.0
# (600, 32, 42, 1) (600, 256)
# episode 46 of 100000 complete,  explore val = 0.955, episode reward = 50.0, ave reward = 50.0
# (603, 32, 42, 1) (603, 256)
# episode 47 of 100000 complete,  explore val = 0.954, episode reward = 50.0, ave reward = 50.0
# (630, 32, 42, 1) (630, 256)
# episode 48 of 100000 complete,  explore val = 0.953, episode reward = 50.0, ave reward = 50.0
# (963, 32, 42, 1) (963, 256)
# episode 49 of 100000 complete,  explore val = 0.952, episode reward = 525.0, ave reward = 525.0
# (633, 32, 42, 1) (633, 256)
# episode 50 of 100000 complete,  explore val = 0.951, episode reward = 75.0, ave reward = 75.0
# (568, 32, 42, 1) (568, 256)
# episode 51 of 100000 complete,  explore val = 0.95, episode reward = 75.0, ave reward = 75.0
# (771, 32, 42, 1) (771, 256)
# episode 52 of 100000 complete,  explore val = 0.949, episode reward = 425.0, ave reward = 425.0
# (600, 32, 42, 1) (600, 256)
# episode 53 of 100000 complete,  explore val = 0.948, episode reward = 50.0, ave reward = 50.0
# (752, 32, 42, 1) (752, 256)
# episode 54 of 100000 complete,  explore val = 0.947, episode reward = 200.0, ave reward = 200.0
# (536, 32, 42, 1) (536, 256)
# episode 55 of 100000 complete,  explore val = 0.946, episode reward = 125.0, ave reward = 125.0
# (668, 32, 42, 1) (668, 256)
# episode 56 of 100000 complete,  explore val = 0.946, episode reward = 100.0, ave reward = 100.0
# (593, 32, 42, 1) (593, 256)
# episode 57 of 100000 complete,  explore val = 0.945, episode reward = 25.0, ave reward = 25.0
# (751, 32, 42, 1) (751, 256)
# episode 58 of 100000 complete,  explore val = 0.944, episode reward = 125.0, ave reward = 125.0
# (903, 32, 42, 1) (903, 256)
# episode 59 of 100000 complete,  explore val = 0.943, episode reward = 200.0, ave reward = 200.0
# (689, 32, 42, 1) (689, 256)
# episode 60 of 100000 complete,  explore val = 0.942, episode reward = 150.0, ave reward = 150.0
# (621, 32, 42, 1) (621, 256)
# episode 61 of 100000 complete,  explore val = 0.941, episode reward = 175.0, ave reward = 175.0
# (661, 32, 42, 1) (661, 256)
# episode 62 of 100000 complete,  explore val = 0.94, episode reward = 225.0, ave reward = 225.0
# (638, 32, 42, 1) (638, 256)
# episode 63 of 100000 complete,  explore val = 0.939, episode reward = 50.0, ave reward = 50.0
# (608, 32, 42, 1) (608, 256)
# episode 64 of 100000 complete,  explore val = 0.938, episode reward = 25.0, ave reward = 25.0
# (956, 32, 42, 1) (956, 256)
# episode 65 of 100000 complete,  explore val = 0.937, episode reward = 625.0, ave reward = 625.0
# (588, 32, 42, 1) (588, 256)
# episode 66 of 100000 complete,  explore val = 0.936, episode reward = 25.0, ave reward = 25.0
# (594, 32, 42, 1) (594, 256)
# episode 67 of 100000 complete,  explore val = 0.935, episode reward = 150.0, ave reward = 150.0
# (813, 32, 42, 1) (813, 256)
# episode 68 of 100000 complete,  explore val = 0.934, episode reward = 125.0, ave reward = 125.0
# (676, 32, 42, 1) (676, 256)
# episode 69 of 100000 complete,  explore val = 0.933, episode reward = 75.0, ave reward = 75.0
# (608, 32, 42, 1) (608, 256)
# episode 70 of 100000 complete,  explore val = 0.932, episode reward = 75.0, ave reward = 75.0
# (658, 32, 42, 1) (658, 256)
# episode 71 of 100000 complete,  explore val = 0.931, episode reward = 100.0, ave reward = 100.0
# (650, 32, 42, 1) (650, 256)
# episode 72 of 100000 complete,  explore val = 0.93, episode reward = 175.0, ave reward = 175.0
# (553, 32, 42, 1) (553, 256)
# episode 73 of 100000 complete,  explore val = 0.93, episode reward = 75.0, ave reward = 75.0
# (627, 32, 42, 1) (627, 256)
# episode 74 of 100000 complete,  explore val = 0.929, episode reward = 75.0, ave reward = 75.0
# (636, 32, 42, 1) (636, 256)
# episode 75 of 100000 complete,  explore val = 0.928, episode reward = 75.0, ave reward = 75.0
# (598, 32, 42, 1) (598, 256)
# episode 76 of 100000 complete,  explore val = 0.927, episode reward = 25.0, ave reward = 25.0
# (726, 32, 42, 1) (726, 256)
# episode 77 of 100000 complete,  explore val = 0.926, episode reward = 225.0, ave reward = 225.0
# (530, 32, 42, 1) (530, 256)
# episode 78 of 100000 complete,  explore val = 0.925, episode reward = 75.0, ave reward = 75.0
# (1255, 32, 42, 1) (1255, 256)
# episode 79 of 100000 complete,  explore val = 0.924, episode reward = 75.0, ave reward = 75.0
# (666, 32, 42, 1) (666, 256)
# episode 80 of 100000 complete,  explore val = 0.923, episode reward = 300.0, ave reward = 300.0
# (591, 32, 42, 1) (591, 256)
# episode 81 of 100000 complete,  explore val = 0.922, episode reward = 25.0, ave reward = 25.0
# (735, 32, 42, 1) (735, 256)
# episode 82 of 100000 complete,  explore val = 0.921, episode reward = 200.0, ave reward = 200.0
# (631, 32, 42, 1) (631, 256)
# episode 83 of 100000 complete,  explore val = 0.92, episode reward = 50.0, ave reward = 50.0
# (641, 32, 42, 1) (641, 256)
# episode 84 of 100000 complete,  explore val = 0.919, episode reward = 75.0, ave reward = 75.0
# (653, 32, 42, 1) (653, 256)
# episode 85 of 100000 complete,  explore val = 0.918, episode reward = 175.0, ave reward = 175.0
# (751, 32, 42, 1) (751, 256)
# episode 86 of 100000 complete,  explore val = 0.918, episode reward = 175.0, ave reward = 175.0
# (961, 32, 42, 1) (961, 256)
# episode 87 of 100000 complete,  explore val = 0.917, episode reward = 300.0, ave reward = 300.0
# (568, 32, 42, 1) (568, 256)
# episode 88 of 100000 complete,  explore val = 0.916, episode reward = 50.0, ave reward = 50.0
# (663, 32, 42, 1) (663, 256)
# episode 89 of 100000 complete,  explore val = 0.915, episode reward = 150.0, ave reward = 150.0
# (710, 32, 42, 1) (710, 256)
# episode 90 of 100000 complete,  explore val = 0.914, episode reward = 200.0, ave reward = 200.0
# (605, 32, 42, 1) (605, 256)
# episode 91 of 100000 complete,  explore val = 0.913, episode reward = 50.0, ave reward = 50.0
# (643, 32, 42, 1) (643, 256)
# episode 92 of 100000 complete,  explore val = 0.912, episode reward = 50.0, ave reward = 50.0
# (813, 32, 42, 1) (813, 256)
# episode 93 of 100000 complete,  explore val = 0.911, episode reward = 100.0, ave reward = 100.0
# (683, 32, 42, 1) (683, 256)
# episode 94 of 100000 complete,  explore val = 0.91, episode reward = 50.0, ave reward = 50.0
# (550, 32, 42, 1) (550, 256)
# episode 95 of 100000 complete,  explore val = 0.909, episode reward = 100.0, ave reward = 100.0
# (638, 32, 42, 1) (638, 256)
# episode 96 of 100000 complete,  explore val = 0.908, episode reward = 125.0, ave reward = 125.0
# (783, 32, 42, 1) (783, 256)
# episode 97 of 100000 complete,  explore val = 0.908, episode reward = 175.0, ave reward = 175.0
# (601, 32, 42, 1) (601, 256)
# episode 98 of 100000 complete,  explore val = 0.907, episode reward = 25.0, ave reward = 25.0
# (773, 32, 42, 1) (773, 256)
# episode 99 of 100000 complete,  explore val = 0.906, episode reward = 225.0, ave reward = 225.0
# (616, 32, 42, 1) (616, 256)
# episode 100 of 100000 complete,  explore val = 0.905, episode reward = 50.0, ave reward = 50.0
# (580, 32, 42, 1) (580, 256)
# episode 101 of 100000 complete,  explore val = 0.904, episode reward = 25.0, ave reward = 144.8
# (683, 32, 42, 1) (683, 256)
# episode 102 of 100000 complete,  explore val = 0.903, episode reward = 475.0, ave reward = 142.2
# (611, 32, 42, 1) (611, 256)
# episode 103 of 100000 complete,  explore val = 0.902, episode reward = 50.0, ave reward = 145.2
# (585, 32, 42, 1) (585, 256)
# episode 104 of 100000 complete,  explore val = 0.901, episode reward = 25.0, ave reward = 145.0
# (1513, 32, 42, 1) (1513, 256)
# episode 105 of 100000 complete,  explore val = 0.9, episode reward = 350.0, ave reward = 143.5
# (702, 32, 42, 1) (702, 256)
# episode 106 of 100000 complete,  explore val = 0.899, episode reward = 175.0, ave reward = 146.2
# (568, 32, 42, 1) (568, 256)
# episode 107 of 100000 complete,  explore val = 0.898, episode reward = 0.0, ave reward = 147.2
# (705, 32, 42, 1) (705, 256)
# episode 108 of 100000 complete,  explore val = 0.898, episode reward = 400.0, ave reward = 145.8
# (601, 32, 42, 1) (601, 256)
# episode 109 of 100000 complete,  explore val = 0.897, episode reward = 75.0, ave reward = 147.8
# (688, 32, 42, 1) (688, 256)
# episode 110 of 100000 complete,  explore val = 0.896, episode reward = 150.0, ave reward = 147.5
# (761, 32, 42, 1) (761, 256)
# episode 111 of 100000 complete,  explore val = 0.895, episode reward = 175.0, ave reward = 149.0
# (546, 32, 42, 1) (546, 256)
# episode 112 of 100000 complete,  explore val = 0.894, episode reward = 50.0, ave reward = 146.5
# (720, 32, 42, 1) (720, 256)
# episode 113 of 100000 complete,  explore val = 0.893, episode reward = 225.0, ave reward = 144.8
# (1744, 32, 42, 1) (1744, 256)
# episode 114 of 100000 complete,  explore val = 0.892, episode reward = 825.0, ave reward = 146.5
# (711, 32, 42, 1) (711, 256)
# episode 115 of 100000 complete,  explore val = 0.891, episode reward = 200.0, ave reward = 153.2
# (593, 32, 42, 1) (593, 256)
# episode 116 of 100000 complete,  explore val = 0.89, episode reward = 100.0, ave reward = 154.5
# (920, 32, 42, 1) (920, 256)
# episode 117 of 100000 complete,  explore val = 0.89, episode reward = 525.0, ave reward = 154.5
# (591, 32, 42, 1) (591, 256)
# episode 118 of 100000 complete,  explore val = 0.889, episode reward = 0.0, ave reward = 159.2
# (708, 32, 42, 1) (708, 256)
# episode 119 of 100000 complete,  explore val = 0.888, episode reward = 275.0, ave reward = 157.8
# (611, 32, 42, 1) (611, 256)
# episode 120 of 100000 complete,  explore val = 0.887, episode reward = 100.0, ave reward = 159.8
# (606, 32, 42, 1) (606, 256)
# episode 121 of 100000 complete,  explore val = 0.886, episode reward = 50.0, ave reward = 158.8
# (575, 32, 42, 1) (575, 256)
# episode 122 of 100000 complete,  explore val = 0.885, episode reward = 0.0, ave reward = 157.0
# (628, 32, 42, 1) (628, 256)
# episode 123 of 100000 complete,  explore val = 0.884, episode reward = 75.0, ave reward = 155.0
# (677, 32, 42, 1) (677, 256)
# episode 124 of 100000 complete,  explore val = 0.883, episode reward = 200.0, ave reward = 153.2
# (542, 32, 42, 1) (542, 256)
# episode 125 of 100000 complete,  explore val = 0.882, episode reward = 75.0, ave reward = 153.2
# (590, 32, 42, 1) (590, 256)
# episode 126 of 100000 complete,  explore val = 0.882, episode reward = 175.0, ave reward = 151.5
# (618, 32, 42, 1) (618, 256)
# episode 127 of 100000 complete,  explore val = 0.881, episode reward = 50.0, ave reward = 151.8
# (686, 32, 42, 1) (686, 256)
# episode 128 of 100000 complete,  explore val = 0.88, episode reward = 75.0, ave reward = 150.5
# (681, 32, 42, 1) (681, 256)
# episode 129 of 100000 complete,  explore val = 0.879, episode reward = 150.0, ave reward = 150.2
# (626, 32, 42, 1) (626, 256)
# episode 130 of 100000 complete,  explore val = 0.878, episode reward = 50.0, ave reward = 150.2
# (575, 32, 42, 1) (575, 256)
# episode 131 of 100000 complete,  explore val = 0.877, episode reward = 125.0, ave reward = 149.8
# (808, 32, 42, 1) (808, 256)
# episode 132 of 100000 complete,  explore val = 0.876, episode reward = 500.0, ave reward = 150.0
# (656, 32, 42, 1) (656, 256)
# episode 133 of 100000 complete,  explore val = 0.875, episode reward = 100.0, ave reward = 153.8
# (728, 32, 42, 1) (728, 256)
# episode 134 of 100000 complete,  explore val = 0.875, episode reward = 475.0, ave reward = 154.0
# (1321, 32, 42, 1) (1321, 256)
# episode 135 of 100000 complete,  explore val = 0.874, episode reward = 275.0, ave reward = 156.0
# (640, 32, 42, 1) (640, 256)
# episode 136 of 100000 complete,  explore val = 0.873, episode reward = 75.0, ave reward = 156.5
# (637, 32, 42, 1) (637, 256)
# episode 137 of 100000 complete,  explore val = 0.872, episode reward = 100.0, ave reward = 156.2
# (701, 32, 42, 1) (701, 256)
# episode 138 of 100000 complete,  explore val = 0.871, episode reward = 125.0, ave reward = 155.0
# (588, 32, 42, 1) (588, 256)
# episode 139 of 100000 complete,  explore val = 0.87, episode reward = 150.0, ave reward = 155.0
# (588, 32, 42, 1) (588, 256)
# episode 140 of 100000 complete,  explore val = 0.869, episode reward = 25.0, ave reward = 154.0
# (706, 32, 42, 1) (706, 256)
# episode 141 of 100000 complete,  explore val = 0.868, episode reward = 100.0, ave reward = 153.2
# (758, 32, 42, 1) (758, 256)
# episode 142 of 100000 complete,  explore val = 0.868, episode reward = 575.0, ave reward = 152.5
# (648, 32, 42, 1) (648, 256)
# episode 143 of 100000 complete,  explore val = 0.867, episode reward = 225.0, ave reward = 156.8
# (575, 32, 42, 1) (575, 256)
# episode 144 of 100000 complete,  explore val = 0.866, episode reward = 0.0, ave reward = 157.0
# (1491, 32, 42, 1) (1491, 256)
# episode 145 of 100000 complete,  explore val = 0.865, episode reward = 425.0, ave reward = 156.8
# (721, 32, 42, 1) (721, 256)
# episode 146 of 100000 complete,  explore val = 0.864, episode reward = 175.0, ave reward = 157.0
# (623, 32, 42, 1) (623, 256)
# episode 147 of 100000 complete,  explore val = 0.863, episode reward = 100.0, ave reward = 158.2
# (545, 32, 42, 1) (545, 256)
# episode 148 of 100000 complete,  explore val = 0.862, episode reward = 75.0, ave reward = 158.8
# (906, 32, 42, 1) (906, 256)
# episode 149 of 100000 complete,  explore val = 0.862, episode reward = 600.0, ave reward = 159.0
# (583, 32, 42, 1) (583, 256)
# episode 150 of 100000 complete,  explore val = 0.861, episode reward = 50.0, ave reward = 159.8
# (580, 32, 42, 1) (580, 256)
# episode 151 of 100000 complete,  explore val = 0.86, episode reward = 125.0, ave reward = 159.5
# (583, 32, 42, 1) (583, 256)
# episode 152 of 100000 complete,  explore val = 0.859, episode reward = 100.0, ave reward = 160.0
# (598, 32, 42, 1) (598, 256)
# episode 153 of 100000 complete,  explore val = 0.858, episode reward = 25.0, ave reward = 156.8
# (628, 32, 42, 1) (628, 256)
# episode 154 of 100000 complete,  explore val = 0.857, episode reward = 75.0, ave reward = 156.5
# (724, 32, 42, 1) (724, 256)
# episode 155 of 100000 complete,  explore val = 0.856, episode reward = 175.0, ave reward = 155.2
# (728, 32, 42, 1) (728, 256)
# episode 156 of 100000 complete,  explore val = 0.855, episode reward = 75.0, ave reward = 155.8
# (814, 32, 42, 1) (814, 256)
# episode 157 of 100000 complete,  explore val = 0.855, episode reward = 225.0, ave reward = 155.5
# (658, 32, 42, 1) (658, 256)
# episode 158 of 100000 complete,  explore val = 0.854, episode reward = 75.0, ave reward = 157.5
# (708, 32, 42, 1) (708, 256)
# episode 159 of 100000 complete,  explore val = 0.853, episode reward = 450.0, ave reward = 157.0
# (696, 32, 42, 1) (696, 256)
# episode 160 of 100000 complete,  explore val = 0.852, episode reward = 225.0, ave reward = 159.5
# (586, 32, 42, 1) (586, 256)
# episode 161 of 100000 complete,  explore val = 0.851, episode reward = 150.0, ave reward = 160.2
# (668, 32, 42, 1) (668, 256)
# episode 162 of 100000 complete,  explore val = 0.85, episode reward = 100.0, ave reward = 160.0
# (648, 32, 42, 1) (648, 256)
# episode 163 of 100000 complete,  explore val = 0.85, episode reward = 75.0, ave reward = 158.8
# (694, 32, 42, 1) (694, 256)
# episode 164 of 100000 complete,  explore val = 0.849, episode reward = 250.0, ave reward = 159.0
# (635, 32, 42, 1) (635, 256)
# episode 165 of 100000 complete,  explore val = 0.848, episode reward = 75.0, ave reward = 161.2
# (530, 32, 42, 1) (530, 256)
# episode 166 of 100000 complete,  explore val = 0.847, episode reward = 100.0, ave reward = 155.8
# (568, 32, 42, 1) (568, 256)
# episode 167 of 100000 complete,  explore val = 0.846, episode reward = 0.0, ave reward = 156.5
# (646, 32, 42, 1) (646, 256)
# episode 168 of 100000 complete,  explore val = 0.845, episode reward = 50.0, ave reward = 155.0
# (725, 32, 42, 1) (725, 256)
# episode 169 of 100000 complete,  explore val = 0.844, episode reward = 125.0, ave reward = 154.2
# (772, 32, 42, 1) (772, 256)
# episode 170 of 100000 complete,  explore val = 0.844, episode reward = 475.0, ave reward = 154.8
# (652, 32, 42, 1) (652, 256)
# episode 171 of 100000 complete,  explore val = 0.843, episode reward = 100.0, ave reward = 158.8
# (651, 32, 42, 1) (651, 256)
# episode 172 of 100000 complete,  explore val = 0.842, episode reward = 50.0, ave reward = 158.8
# (677, 32, 42, 1) (677, 256)
# episode 173 of 100000 complete,  explore val = 0.841, episode reward = 175.0, ave reward = 157.5
# (635, 32, 42, 1) (635, 256)
# episode 174 of 100000 complete,  explore val = 0.84, episode reward = 75.0, ave reward = 158.5
# (578, 32, 42, 1) (578, 256)
# episode 175 of 100000 complete,  explore val = 0.839, episode reward = 0.0, ave reward = 158.5
# (798, 32, 42, 1) (798, 256)
# episode 176 of 100000 complete,  explore val = 0.839, episode reward = 625.0, ave reward = 157.8
# (865, 32, 42, 1) (865, 256)
# episode 177 of 100000 complete,  explore val = 0.838, episode reward = 600.0, ave reward = 163.8
# (581, 32, 42, 1) (581, 256)
# episode 178 of 100000 complete,  explore val = 0.837, episode reward = 50.0, ave reward = 167.5
# (776, 32, 42, 1) (776, 256)
# episode 179 of 100000 complete,  explore val = 0.836, episode reward = 500.0, ave reward = 167.2
# (615, 32, 42, 1) (615, 256)
# episode 180 of 100000 complete,  explore val = 0.835, episode reward = 50.0, ave reward = 171.5
# (1508, 32, 42, 1) (1508, 256)
# episode 181 of 100000 complete,  explore val = 0.834, episode reward = 650.0, ave reward = 169.0
# (1334, 32, 42, 1) (1334, 256)
# episode 182 of 100000 complete,  explore val = 0.834, episode reward = 450.0, ave reward = 175.2
# (608, 32, 42, 1) (608, 256)
# episode 183 of 100000 complete,  explore val = 0.833, episode reward = 50.0, ave reward = 177.8
# (652, 32, 42, 1) (652, 256)
# episode 184 of 100000 complete,  explore val = 0.832, episode reward = 150.0, ave reward = 177.8
# (538, 32, 42, 1) (538, 256)
# episode 185 of 100000 complete,  explore val = 0.831, episode reward = 75.0, ave reward = 178.5
# (696, 32, 42, 1) (696, 256)
# episode 186 of 100000 complete,  explore val = 0.83, episode reward = 425.0, ave reward = 177.5
# (523, 32, 42, 1) (523, 256)
# episode 187 of 100000 complete,  explore val = 0.829, episode reward = 50.0, ave reward = 180.0
# (635, 32, 42, 1) (635, 256)
# episode 188 of 100000 complete,  explore val = 0.829, episode reward = 225.0, ave reward = 177.5
# (621, 32, 42, 1) (621, 256)
# episode 189 of 100000 complete,  explore val = 0.828, episode reward = 50.0, ave reward = 179.2
# (656, 32, 42, 1) (656, 256)
# episode 190 of 100000 complete,  explore val = 0.827, episode reward = 150.0, ave reward = 178.2
# (808, 32, 42, 1) (808, 256)
# episode 191 of 100000 complete,  explore val = 0.826, episode reward = 250.0, ave reward = 177.8
# (617, 32, 42, 1) (617, 256)
# episode 192 of 100000 complete,  explore val = 0.825, episode reward = 250.0, ave reward = 179.8
# (663, 32, 42, 1) (663, 256)
# episode 193 of 100000 complete,  explore val = 0.824, episode reward = 175.0, ave reward = 181.8
# (948, 32, 42, 1) (948, 256)
# episode 194 of 100000 complete,  explore val = 0.824, episode reward = 325.0, ave reward = 182.5
# (636, 32, 42, 1) (636, 256)
# episode 195 of 100000 complete,  explore val = 0.823, episode reward = 100.0, ave reward = 185.2
# (673, 32, 42, 1) (673, 256)
# episode 196 of 100000 complete,  explore val = 0.822, episode reward = 400.0, ave reward = 185.2
# (535, 32, 42, 1) (535, 256)
# episode 197 of 100000 complete,  explore val = 0.821, episode reward = 75.0, ave reward = 188.0
# (626, 32, 42, 1) (626, 256)
# episode 198 of 100000 complete,  explore val = 0.82, episode reward = 50.0, ave reward = 187.0
# (696, 32, 42, 1) (696, 256)
# episode 199 of 100000 complete,  explore val = 0.819, episode reward = 125.0, ave reward = 187.2
# (836, 32, 42, 1) (836, 256)
# episode 200 of 100000 complete,  explore val = 0.819, episode reward = 200.0, ave reward = 186.2
# (553, 32, 42, 1) (553, 256)
# episode 201 of 100000 complete,  explore val = 0.818, episode reward = 50.0, ave reward = 187.8
# (901, 32, 42, 1) (901, 256)
# episode 202 of 100000 complete,  explore val = 0.817, episode reward = 350.0, ave reward = 188.0
# (754, 32, 42, 1) (754, 256)
# episode 203 of 100000 complete,  explore val = 0.816, episode reward = 275.0, ave reward = 186.8
# (538, 32, 42, 1) (538, 256)
# episode 204 of 100000 complete,  explore val = 0.815, episode reward = 125.0, ave reward = 189.0
# (1230, 32, 42, 1) (1230, 256)
# episode 205 of 100000 complete,  explore val = 0.815, episode reward = 125.0, ave reward = 190.0
# (561, 32, 42, 1) (561, 256)
# episode 206 of 100000 complete,  explore val = 0.814, episode reward = 75.0, ave reward = 187.8
# (1250, 32, 42, 1) (1250, 256)
# episode 207 of 100000 complete,  explore val = 0.813, episode reward = 175.0, ave reward = 186.8
# (688, 32, 42, 1) (688, 256)
# episode 208 of 100000 complete,  explore val = 0.812, episode reward = 125.0, ave reward = 188.5
# (610, 32, 42, 1) (610, 256)
# episode 209 of 100000 complete,  explore val = 0.811, episode reward = 50.0, ave reward = 185.8
# (646, 32, 42, 1) (646, 256)
# episode 210 of 100000 complete,  explore val = 0.81, episode reward = 75.0, ave reward = 185.5
# (560, 32, 42, 1) (560, 256)
# episode 211 of 100000 complete,  explore val = 0.81, episode reward = 0.0, ave reward = 184.8
# (637, 32, 42, 1) (637, 256)
# episode 212 of 100000 complete,  explore val = 0.809, episode reward = 100.0, ave reward = 183.0
# (631, 32, 42, 1) (631, 256)
# episode 213 of 100000 complete,  explore val = 0.808, episode reward = 50.0, ave reward = 183.5
# (640, 32, 42, 1) (640, 256)
# episode 214 of 100000 complete,  explore val = 0.807, episode reward = 100.0, ave reward = 181.8
# (598, 32, 42, 1) (598, 256)
# episode 215 of 100000 complete,  explore val = 0.806, episode reward = 50.0, ave reward = 174.5
# (565, 32, 42, 1) (565, 256)
# episode 216 of 100000 complete,  explore val = 0.806, episode reward = 0.0, ave reward = 173.0
# (680, 32, 42, 1) (680, 256)
# episode 217 of 100000 complete,  explore val = 0.805, episode reward = 150.0, ave reward = 172.0
# (1189, 32, 42, 1) (1189, 256)
# episode 218 of 100000 complete,  explore val = 0.804, episode reward = 125.0, ave reward = 168.2
# (628, 32, 42, 1) (628, 256)
# episode 219 of 100000 complete,  explore val = 0.803, episode reward = 25.0, ave reward = 169.5
# (545, 32, 42, 1) (545, 256)
# episode 220 of 100000 complete,  explore val = 0.802, episode reward = 100.0, ave reward = 167.0
# (1422, 32, 42, 1) (1422, 256)
# episode 221 of 100000 complete,  explore val = 0.802, episode reward = 300.0, ave reward = 167.0
# (533, 32, 42, 1) (533, 256)
# episode 222 of 100000 complete,  explore val = 0.801, episode reward = 75.0, ave reward = 169.5
# (637, 32, 42, 1) (637, 256)
# episode 223 of 100000 complete,  explore val = 0.8, episode reward = 150.0, ave reward = 170.2
# (645, 32, 42, 1) (645, 256)
# episode 224 of 100000 complete,  explore val = 0.799, episode reward = 150.0, ave reward = 171.0
# (570, 32, 42, 1) (570, 256)
# episode 225 of 100000 complete,  explore val = 0.798, episode reward = 125.0, ave reward = 170.5
# (586, 32, 42, 1) (586, 256)
# episode 226 of 100000 complete,  explore val = 0.798, episode reward = 100.0, ave reward = 171.0
# (746, 32, 42, 1) (746, 256)
# episode 227 of 100000 complete,  explore val = 0.797, episode reward = 225.0, ave reward = 170.2
# (690, 32, 42, 1) (690, 256)
# episode 228 of 100000 complete,  explore val = 0.796, episode reward = 100.0, ave reward = 172.0
# (638, 32, 42, 1) (638, 256)
# episode 229 of 100000 complete,  explore val = 0.795, episode reward = 125.0, ave reward = 172.2
# (565, 32, 42, 1) (565, 256)
# episode 230 of 100000 complete,  explore val = 0.794, episode reward = 0.0, ave reward = 172.0
# (768, 32, 42, 1) (768, 256)
# episode 231 of 100000 complete,  explore val = 0.794, episode reward = 100.0, ave reward = 171.5
# (936, 32, 42, 1) (936, 256)
# episode 232 of 100000 complete,  explore val = 0.793, episode reward = 550.0, ave reward = 171.2
# (641, 32, 42, 1) (641, 256)
# episode 233 of 100000 complete,  explore val = 0.792, episode reward = 250.0, ave reward = 171.8
# (576, 32, 42, 1) (576, 256)
# episode 234 of 100000 complete,  explore val = 0.791, episode reward = 0.0, ave reward = 173.2
# (536, 32, 42, 1) (536, 256)
# episode 235 of 100000 complete,  explore val = 0.79, episode reward = 50.0, ave reward = 168.5
# (676, 32, 42, 1) (676, 256)
# episode 236 of 100000 complete,  explore val = 0.79, episode reward = 175.0, ave reward = 166.2
# (605, 32, 42, 1) (605, 256)
# episode 237 of 100000 complete,  explore val = 0.789, episode reward = 50.0, ave reward = 167.2
# (687, 32, 42, 1) (687, 256)
# episode 238 of 100000 complete,  explore val = 0.788, episode reward = 175.0, ave reward = 166.8
# (1011, 32, 42, 1) (1011, 256)
# episode 239 of 100000 complete,  explore val = 0.787, episode reward = 275.0, ave reward = 167.2
# (566, 32, 42, 1) (566, 256)
# episode 240 of 100000 complete,  explore val = 0.787, episode reward = 100.0, ave reward = 168.5
# (598, 32, 42, 1) (598, 256)
# episode 241 of 100000 complete,  explore val = 0.786, episode reward = 25.0, ave reward = 169.2
# (641, 32, 42, 1) (641, 256)
# episode 242 of 100000 complete,  explore val = 0.785, episode reward = 75.0, ave reward = 168.5
# (591, 32, 42, 1) (591, 256)
# episode 243 of 100000 complete,  explore val = 0.784, episode reward = 25.0, ave reward = 163.5
# (761, 32, 42, 1) (761, 256)
# episode 244 of 100000 complete,  explore val = 0.783, episode reward = 175.0, ave reward = 161.5
# (558, 32, 42, 1) (558, 256)
# episode 245 of 100000 complete,  explore val = 0.783, episode reward = 50.0, ave reward = 163.2
# (802, 32, 42, 1) (802, 256)
# episode 246 of 100000 complete,  explore val = 0.782, episode reward = 225.0, ave reward = 159.5
# (638, 32, 42, 1) (638, 256)
# episode 247 of 100000 complete,  explore val = 0.781, episode reward = 75.0, ave reward = 160.0
# (902, 32, 42, 1) (902, 256)
# episode 248 of 100000 complete,  explore val = 0.78, episode reward = 275.0, ave reward = 159.8
# (672, 32, 42, 1) (672, 256)
# episode 249 of 100000 complete,  explore val = 0.779, episode reward = 125.0, ave reward = 161.8
# (537, 32, 42, 1) (537, 256)
# episode 250 of 100000 complete,  explore val = 0.779, episode reward = 175.0, ave reward = 157.0
# (905, 32, 42, 1) (905, 256)
# episode 251 of 100000 complete,  explore val = 0.778, episode reward = 375.0, ave reward = 158.2
# (543, 32, 42, 1) (543, 256)
# episode 252 of 100000 complete,  explore val = 0.777, episode reward = 50.0, ave reward = 160.8
# (613, 32, 42, 1) (613, 256)
# episode 253 of 100000 complete,  explore val = 0.776, episode reward = 150.0, ave reward = 160.2
# (1233, 32, 42, 1) (1233, 256)
# episode 254 of 100000 complete,  explore val = 0.776, episode reward = 225.0, ave reward = 161.5
# (732, 32, 42, 1) (732, 256)
# episode 255 of 100000 complete,  explore val = 0.775, episode reward = 100.0, ave reward = 163.0
# (610, 32, 42, 1) (610, 256)
# episode 256 of 100000 complete,  explore val = 0.774, episode reward = 125.0, ave reward = 162.2
# (1235, 32, 42, 1) (1235, 256)
# episode 257 of 100000 complete,  explore val = 0.773, episode reward = 250.0, ave reward = 162.8
# (565, 32, 42, 1) (565, 256)
# episode 258 of 100000 complete,  explore val = 0.772, episode reward = 100.0, ave reward = 163.0
# (508, 32, 42, 1) (508, 256)
# episode 259 of 100000 complete,  explore val = 0.772, episode reward = 50.0, ave reward = 163.2
# (652, 32, 42, 1) (652, 256)
# episode 260 of 100000 complete,  explore val = 0.771, episode reward = 200.0, ave reward = 159.2
# (638, 32, 42, 1) (638, 256)
# episode 261 of 100000 complete,  explore val = 0.77, episode reward = 75.0, ave reward = 159.0
# (870, 32, 42, 1) (870, 256)
# episode 262 of 100000 complete,  explore val = 0.769, episode reward = 625.0, ave reward = 158.2
# (745, 32, 42, 1) (745, 256)
# episode 263 of 100000 complete,  explore val = 0.769, episode reward = 150.0, ave reward = 163.5
# (893, 32, 42, 1) (893, 256)
# episode 264 of 100000 complete,  explore val = 0.768, episode reward = 250.0, ave reward = 164.2
# (717, 32, 42, 1) (717, 256)
# episode 265 of 100000 complete,  explore val = 0.767, episode reward = 200.0, ave reward = 164.2
# (755, 32, 42, 1) (755, 256)
# episode 266 of 100000 complete,  explore val = 0.766, episode reward = 150.0, ave reward = 165.5
# (963, 32, 42, 1) (963, 256)
# episode 267 of 100000 complete,  explore val = 0.766, episode reward = 375.0, ave reward = 166.0
# (668, 32, 42, 1) (668, 256)
# episode 268 of 100000 complete,  explore val = 0.765, episode reward = 75.0, ave reward = 169.8
# (728, 32, 42, 1) (728, 256)
# episode 269 of 100000 complete,  explore val = 0.764, episode reward = 200.0, ave reward = 170.0
# (571, 32, 42, 1) (571, 256)
# episode 270 of 100000 complete,  explore val = 0.763, episode reward = 125.0, ave reward = 170.8
# (1003, 32, 42, 1) (1003, 256)
# episode 271 of 100000 complete,  explore val = 0.763, episode reward = 525.0, ave reward = 167.2
# (646, 32, 42, 1) (646, 256)
# episode 272 of 100000 complete,  explore val = 0.762, episode reward = 50.0, ave reward = 171.5
# (578, 32, 42, 1) (578, 256)
# episode 273 of 100000 complete,  explore val = 0.761, episode reward = 0.0, ave reward = 171.5
# (1568, 32, 42, 1) (1568, 256)
# episode 274 of 100000 complete,  explore val = 0.76, episode reward = 450.0, ave reward = 169.8
# (570, 32, 42, 1) (570, 256)
# episode 275 of 100000 complete,  explore val = 0.759, episode reward = 25.0, ave reward = 173.5
# (561, 32, 42, 1) (561, 256)
# episode 276 of 100000 complete,  explore val = 0.759, episode reward = 100.0, ave reward = 173.8
# (650, 32, 42, 1) (650, 256)
# episode 277 of 100000 complete,  explore val = 0.758, episode reward = 125.0, ave reward = 168.5
# (626, 32, 42, 1) (626, 256)
# episode 278 of 100000 complete,  explore val = 0.757, episode reward = 75.0, ave reward = 163.8
# (862, 32, 42, 1) (862, 256)
# episode 279 of 100000 complete,  explore val = 0.756, episode reward = 525.0, ave reward = 164.0
# (752, 32, 42, 1) (752, 256)
# episode 280 of 100000 complete,  explore val = 0.756, episode reward = 150.0, ave reward = 164.2
# (596, 32, 42, 1) (596, 256)
# episode 281 of 100000 complete,  explore val = 0.755, episode reward = 150.0, ave reward = 165.2
# (701, 32, 42, 1) (701, 256)
# episode 282 of 100000 complete,  explore val = 0.754, episode reward = 175.0, ave reward = 160.2
# (643, 32, 42, 1) (643, 256)
# episode 283 of 100000 complete,  explore val = 0.753, episode reward = 100.0, ave reward = 157.5
# (993, 32, 42, 1) (993, 256)
# episode 284 of 100000 complete,  explore val = 0.753, episode reward = 200.0, ave reward = 158.0
# (635, 32, 42, 1) (635, 256)
# episode 285 of 100000 complete,  explore val = 0.752, episode reward = 200.0, ave reward = 158.5
# (674, 32, 42, 1) (674, 256)
# episode 286 of 100000 complete,  explore val = 0.751, episode reward = 225.0, ave reward = 159.8
# (786, 32, 42, 1) (786, 256)
# episode 287 of 100000 complete,  explore val = 0.75, episode reward = 200.0, ave reward = 157.8
# (800, 32, 42, 1) (800, 256)
# episode 288 of 100000 complete,  explore val = 0.75, episode reward = 300.0, ave reward = 159.2
# (551, 32, 42, 1) (551, 256)
# episode 289 of 100000 complete,  explore val = 0.749, episode reward = 75.0, ave reward = 160.0
# (690, 32, 42, 1) (690, 256)
# episode 290 of 100000 complete,  explore val = 0.748, episode reward = 175.0, ave reward = 160.2
# (741, 32, 42, 1) (741, 256)
# episode 291 of 100000 complete,  explore val = 0.747, episode reward = 75.0, ave reward = 160.5
# (628, 32, 42, 1) (628, 256)
# episode 292 of 100000 complete,  explore val = 0.747, episode reward = 150.0, ave reward = 158.8
# (593, 32, 42, 1) (593, 256)
# episode 293 of 100000 complete,  explore val = 0.746, episode reward = 0.0, ave reward = 157.8
# (918, 32, 42, 1) (918, 256)
# episode 294 of 100000 complete,  explore val = 0.745, episode reward = 325.0, ave reward = 156.0
# (498, 32, 42, 1) (498, 256)
# episode 295 of 100000 complete,  explore val = 0.744, episode reward = 25.0, ave reward = 156.0
# (638, 32, 42, 1) (638, 256)
# episode 296 of 100000 complete,  explore val = 0.744, episode reward = 100.0, ave reward = 155.2
# (668, 32, 42, 1) (668, 256)
# episode 297 of 100000 complete,  explore val = 0.743, episode reward = 200.0, ave reward = 152.2
# (884, 32, 42, 1) (884, 256)
# episode 298 of 100000 complete,  explore val = 0.742, episode reward = 300.0, ave reward = 153.5
# (518, 32, 42, 1) (518, 256)
# episode 299 of 100000 complete,  explore val = 0.741, episode reward = 50.0, ave reward = 156.0
# (731, 32, 42, 1) (731, 256)
# episode 300 of 100000 complete,  explore val = 0.741, episode reward = 175.0, ave reward = 155.2
# (613, 32, 42, 1) (613, 256)
# episode 301 of 100000 complete,  explore val = 0.74, episode reward = 50.0, ave reward = 155.0
# (518, 32, 42, 1) (518, 256)
# episode 302 of 100000 complete,  explore val = 0.739, episode reward = 25.0, ave reward = 155.0
# (606, 32, 42, 1) (606, 256)
# episode 303 of 100000 complete,  explore val = 0.738, episode reward = 25.0, ave reward = 151.8
# (630, 32, 42, 1) (630, 256)
# episode 304 of 100000 complete,  explore val = 0.738, episode reward = 75.0, ave reward = 149.2
# (691, 32, 42, 1) (691, 256)
# episode 305 of 100000 complete,  explore val = 0.737, episode reward = 200.0, ave reward = 148.8
# (841, 32, 42, 1) (841, 256)
# episode 306 of 100000 complete,  explore val = 0.736, episode reward = 175.0, ave reward = 149.5
# (758, 32, 42, 1) (758, 256)
# episode 307 of 100000 complete,  explore val = 0.736, episode reward = 225.0, ave reward = 150.5
# (553, 32, 42, 1) (553, 256)
# episode 308 of 100000 complete,  explore val = 0.735, episode reward = 50.0, ave reward = 151.0
# (714, 32, 42, 1) (714, 256)
# episode 309 of 100000 complete,  explore val = 0.734, episode reward = 225.0, ave reward = 150.2
# (573, 32, 42, 1) (573, 256)
# episode 310 of 100000 complete,  explore val = 0.733, episode reward = 0.0, ave reward = 152.0
# (878, 32, 42, 1) (878, 256)
# episode 311 of 100000 complete,  explore val = 0.733, episode reward = 525.0, ave reward = 151.2
# (688, 32, 42, 1) (688, 256)
# episode 312 of 100000 complete,  explore val = 0.732, episode reward = 125.0, ave reward = 156.5
# (705, 32, 42, 1) (705, 256)
# episode 313 of 100000 complete,  explore val = 0.731, episode reward = 200.0, ave reward = 156.8
# (642, 32, 42, 1) (642, 256)
# episode 314 of 100000 complete,  explore val = 0.73, episode reward = 100.0, ave reward = 158.2
# (548, 32, 42, 1) (548, 256)
# episode 315 of 100000 complete,  explore val = 0.73, episode reward = 125.0, ave reward = 158.2
# (797, 32, 42, 1) (797, 256)
# episode 316 of 100000 complete,  explore val = 0.729, episode reward = 250.0, ave reward = 159.0
# (695, 32, 42, 1) (695, 256)
# episode 317 of 100000 complete,  explore val = 0.728, episode reward = 225.0, ave reward = 161.5
# (637, 32, 42, 1) (637, 256)
# episode 318 of 100000 complete,  explore val = 0.727, episode reward = 75.0, ave reward = 162.2
# (1443, 32, 42, 1) (1443, 256)
# episode 319 of 100000 complete,  explore val = 0.727, episode reward = 425.0, ave reward = 161.8
# (548, 32, 42, 1) (548, 256)
# episode 320 of 100000 complete,  explore val = 0.726, episode reward = 50.0, ave reward = 165.8
# (738, 32, 42, 1) (738, 256)
# episode 321 of 100000 complete,  explore val = 0.725, episode reward = 75.0, ave reward = 165.2
# (528, 32, 42, 1) (528, 256)
# episode 322 of 100000 complete,  explore val = 0.725, episode reward = 25.0, ave reward = 163.0
# (761, 32, 42, 1) (761, 256)
# episode 323 of 100000 complete,  explore val = 0.724, episode reward = 100.0, ave reward = 162.5
# (541, 32, 42, 1) (541, 256)
# episode 324 of 100000 complete,  explore val = 0.723, episode reward = 50.0, ave reward = 162.0
# (565, 32, 42, 1) (565, 256)
# episode 325 of 100000 complete,  explore val = 0.722, episode reward = 0.0, ave reward = 161.0
# (566, 32, 42, 1) (566, 256)
# episode 326 of 100000 complete,  explore val = 0.722, episode reward = 100.0, ave reward = 159.8
# (656, 32, 42, 1) (656, 256)
# episode 327 of 100000 complete,  explore val = 0.721, episode reward = 75.0, ave reward = 159.8
# (570, 32, 42, 1) (570, 256)
# episode 328 of 100000 complete,  explore val = 0.72, episode reward = 0.0, ave reward = 158.2
# (628, 32, 42, 1) (628, 256)
# episode 329 of 100000 complete,  explore val = 0.72, episode reward = 75.0, ave reward = 157.2
# (648, 32, 42, 1) (648, 256)
# episode 330 of 100000 complete,  explore val = 0.719, episode reward = 75.0, ave reward = 156.8
# (616, 32, 42, 1) (616, 256)
# episode 331 of 100000 complete,  explore val = 0.718, episode reward = 150.0, ave reward = 157.5
# (568, 32, 42, 1) (568, 256)
# episode 332 of 100000 complete,  explore val = 0.717, episode reward = 0.0, ave reward = 158.0
# (518, 32, 42, 1) (518, 256)
# episode 333 of 100000 complete,  explore val = 0.717, episode reward = 75.0, ave reward = 152.5
# (813, 32, 42, 1) (813, 256)
# episode 334 of 100000 complete,  explore val = 0.716, episode reward = 250.0, ave reward = 150.8
# (588, 32, 42, 1) (588, 256)
# episode 335 of 100000 complete,  explore val = 0.715, episode reward = 125.0, ave reward = 153.2
# (623, 32, 42, 1) (623, 256)
# episode 336 of 100000 complete,  explore val = 0.715, episode reward = 50.0, ave reward = 154.0
# (778, 32, 42, 1) (778, 256)
# episode 337 of 100000 complete,  explore val = 0.714, episode reward = 525.0, ave reward = 152.8
# (621, 32, 42, 1) (621, 256)
# episode 338 of 100000 complete,  explore val = 0.713, episode reward = 50.0, ave reward = 157.5
# (822, 32, 42, 1) (822, 256)
# episode 339 of 100000 complete,  explore val = 0.712, episode reward = 250.0, ave reward = 156.2
# (618, 32, 42, 1) (618, 256)
# episode 340 of 100000 complete,  explore val = 0.712, episode reward = 75.0, ave reward = 156.0
# (590, 32, 42, 1) (590, 256)
# episode 341 of 100000 complete,  explore val = 0.711, episode reward = 25.0, ave reward = 155.8
# (565, 32, 42, 1) (565, 256)
# episode 342 of 100000 complete,  explore val = 0.71, episode reward = 0.0, ave reward = 155.8
# (674, 32, 42, 1) (674, 256)
# episode 343 of 100000 complete,  explore val = 0.71, episode reward = 175.0, ave reward = 155.0
# (691, 32, 42, 1) (691, 256)
# episode 344 of 100000 complete,  explore val = 0.709, episode reward = 225.0, ave reward = 156.5
# (563, 32, 42, 1) (563, 256)
# episode 345 of 100000 complete,  explore val = 0.708, episode reward = 50.0, ave reward = 157.0
# (681, 32, 42, 1) (681, 256)
# episode 346 of 100000 complete,  explore val = 0.707, episode reward = 150.0, ave reward = 157.0
# (857, 32, 42, 1) (857, 256)
# episode 347 of 100000 complete,  explore val = 0.707, episode reward = 550.0, ave reward = 156.2
# (573, 32, 42, 1) (573, 256)
# episode 348 of 100000 complete,  explore val = 0.706, episode reward = 0.0, ave reward = 161.0
# (693, 32, 42, 1) (693, 256)
# episode 349 of 100000 complete,  explore val = 0.705, episode reward = 100.0, ave reward = 158.2
# (948, 32, 42, 1) (948, 256)
# episode 350 of 100000 complete,  explore val = 0.705, episode reward = 575.0, ave reward = 158.0
# (833, 32, 42, 1) (833, 256)
# episode 351 of 100000 complete,  explore val = 0.704, episode reward = 200.0, ave reward = 162.0
# (705, 32, 42, 1) (705, 256)
# episode 352 of 100000 complete,  explore val = 0.703, episode reward = 175.0, ave reward = 160.2
# (671, 32, 42, 1) (671, 256)
# episode 353 of 100000 complete,  explore val = 0.702, episode reward = 150.0, ave reward = 161.5
# (508, 32, 42, 1) (508, 256)
# episode 354 of 100000 complete,  explore val = 0.702, episode reward = 50.0, ave reward = 161.5
# (756, 32, 42, 1) (756, 256)
# episode 355 of 100000 complete,  explore val = 0.701, episode reward = 425.0, ave reward = 159.8
# (763, 32, 42, 1) (763, 256)
# episode 356 of 100000 complete,  explore val = 0.7, episode reward = 225.0, ave reward = 163.0
# (820, 32, 42, 1) (820, 256)
# episode 357 of 100000 complete,  explore val = 0.7, episode reward = 225.0, ave reward = 164.0
# (631, 32, 42, 1) (631, 256)
# episode 358 of 100000 complete,  explore val = 0.699, episode reward = 75.0, ave reward = 163.8
# (603, 32, 42, 1) (603, 256)
# episode 359 of 100000 complete,  explore val = 0.698, episode reward = 75.0, ave reward = 163.5
# (610, 32, 42, 1) (610, 256)
# episode 360 of 100000 complete,  explore val = 0.698, episode reward = 50.0, ave reward = 163.8
# (603, 32, 42, 1) (603, 256)
# episode 361 of 100000 complete,  explore val = 0.697, episode reward = 175.0, ave reward = 162.2
# (583, 32, 42, 1) (583, 256)
# episode 362 of 100000 complete,  explore val = 0.696, episode reward = 0.0, ave reward = 163.2
# (608, 32, 42, 1) (608, 256)
# episode 363 of 100000 complete,  explore val = 0.695, episode reward = 50.0, ave reward = 157.0
# (616, 32, 42, 1) (616, 256)
# episode 364 of 100000 complete,  explore val = 0.695, episode reward = 50.0, ave reward = 156.0
# (588, 32, 42, 1) (588, 256)
# episode 365 of 100000 complete,  explore val = 0.694, episode reward = 100.0, ave reward = 154.0
# (620, 32, 42, 1) (620, 256)
# episode 366 of 100000 complete,  explore val = 0.693, episode reward = 50.0, ave reward = 153.0
# (913, 32, 42, 1) (913, 256)
# episode 367 of 100000 complete,  explore val = 0.693, episode reward = 250.0, ave reward = 152.0
# (701, 32, 42, 1) (701, 256)
# episode 368 of 100000 complete,  explore val = 0.692, episode reward = 275.0, ave reward = 150.8
# (909, 32, 42, 1) (909, 256)
# episode 369 of 100000 complete,  explore val = 0.691, episode reward = 650.0, ave reward = 152.8
# (597, 32, 42, 1) (597, 256)
# episode 370 of 100000 complete,  explore val = 0.691, episode reward = 125.0, ave reward = 157.2
# (941, 32, 42, 1) (941, 256)
# episode 371 of 100000 complete,  explore val = 0.69, episode reward = 600.0, ave reward = 157.2
# (698, 32, 42, 1) (698, 256)
# episode 372 of 100000 complete,  explore val = 0.689, episode reward = 150.0, ave reward = 158.0
# (855, 32, 42, 1) (855, 256)
# episode 373 of 100000 complete,  explore val = 0.689, episode reward = 550.0, ave reward = 159.0
# (548, 32, 42, 1) (548, 256)
# episode 374 of 100000 complete,  explore val = 0.688, episode reward = 100.0, ave reward = 164.5
# (853, 32, 42, 1) (853, 256)
# episode 375 of 100000 complete,  explore val = 0.687, episode reward = 525.0, ave reward = 161.0
# (1312, 32, 42, 1) (1312, 256)
# episode 376 of 100000 complete,  explore val = 0.686, episode reward = 225.0, ave reward = 166.0
# (598, 32, 42, 1) (598, 256)
# episode 377 of 100000 complete,  explore val = 0.686, episode reward = 100.0, ave reward = 167.2
# (655, 32, 42, 1) (655, 256)
# episode 378 of 100000 complete,  explore val = 0.685, episode reward = 200.0, ave reward = 167.0
# (631, 32, 42, 1) (631, 256)
# episode 379 of 100000 complete,  explore val = 0.684, episode reward = 75.0, ave reward = 168.2
# (612, 32, 42, 1) (612, 256)
# episode 380 of 100000 complete,  explore val = 0.684, episode reward = 125.0, ave reward = 163.8
# (546, 32, 42, 1) (546, 256)
# episode 381 of 100000 complete,  explore val = 0.683, episode reward = 75.0, ave reward = 163.5
# (586, 32, 42, 1) (586, 256)
# episode 382 of 100000 complete,  explore val = 0.682, episode reward = 0.0, ave reward = 162.8
# (713, 32, 42, 1) (713, 256)
# episode 383 of 100000 complete,  explore val = 0.682, episode reward = 100.0, ave reward = 161.0
# (770, 32, 42, 1) (770, 256)
# episode 384 of 100000 complete,  explore val = 0.681, episode reward = 225.0, ave reward = 161.0
# (637, 32, 42, 1) (637, 256)
# ...
# episode 14547 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 181.8
# (653, 32, 42, 1) (653, 256)
# episode 14548 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 182.2
# (691, 32, 42, 1) (691, 256)
# episode 14549 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 177.5
# (578, 32, 42, 1) (578, 256)
# episode 14550 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 178.5
# (828, 32, 42, 1) (828, 256)
# episode 14551 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 175.2
# (578, 32, 42, 1) (578, 256)
# episode 14552 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 177.0
# (562, 32, 42, 1) (562, 256)
# episode 14553 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 174.8
# (521, 32, 42, 1) (521, 256)
# episode 14554 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 174.2
# (570, 32, 42, 1) (570, 256)
# episode 14555 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 173.2
# (638, 32, 42, 1) (638, 256)
# episode 14556 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 172.8
# (740, 32, 42, 1) (740, 256)
# episode 14557 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 171.2
# (588, 32, 42, 1) (588, 256)
# episode 14558 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 169.2
# (595, 32, 42, 1) (595, 256)
# episode 14559 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 167.2
# (1208, 32, 42, 1) (1208, 256)
# episode 14560 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 167.0
# (685, 32, 42, 1) (685, 256)
# episode 14561 of 100000 complete,  explore val = 0.01, episode reward = 275.0, ave reward = 167.8
# (663, 32, 42, 1) (663, 256)
# episode 14562 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 169.0
# (703, 32, 42, 1) (703, 256)
# episode 14563 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 171.0
# (655, 32, 42, 1) (655, 256)
# episode 14564 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 170.2
# (605, 32, 42, 1) (605, 256)
# episode 14565 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 171.0
# (578, 32, 42, 1) (578, 256)
# episode 14566 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 170.5
# (656, 32, 42, 1) (656, 256)
# episode 14567 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 169.5
# (810, 32, 42, 1) (810, 256)
# episode 14568 of 100000 complete,  explore val = 0.01, episode reward = 575.0, ave reward = 166.0
# (741, 32, 42, 1) (741, 256)
# episode 14569 of 100000 complete,  explore val = 0.01, episode reward = 525.0, ave reward = 170.8
# (801, 32, 42, 1) (801, 256)
# episode 14570 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 175.2
# (880, 32, 42, 1) (880, 256)
# episode 14571 of 100000 complete,  explore val = 0.01, episode reward = 475.0, ave reward = 174.2
# (576, 32, 42, 1) (576, 256)
# episode 14572 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 178.8
# (548, 32, 42, 1) (548, 256)
# episode 14573 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 176.5
# (673, 32, 42, 1) (673, 256)
# episode 14574 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 176.0
# (498, 32, 42, 1) (498, 256)
# episode 14575 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 177.2
# (606, 32, 42, 1) (606, 256)
# episode 14576 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 177.2
# (706, 32, 42, 1) (706, 256)
# episode 14577 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 176.0
# (620, 32, 42, 1) (620, 256)
# episode 14578 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 174.5
# (768, 32, 42, 1) (768, 256)
# episode 14579 of 100000 complete,  explore val = 0.01, episode reward = 275.0, ave reward = 173.8
# (563, 32, 42, 1) (563, 256)
# episode 14580 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 176.0
# (848, 32, 42, 1) (848, 256)
# episode 14581 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 172.2
# (695, 32, 42, 1) (695, 256)
# episode 14582 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 172.2
# (590, 32, 42, 1) (590, 256)
# episode 14583 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 173.0
# (638, 32, 42, 1) (638, 256)
# episode 14584 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 171.5
# (800, 32, 42, 1) (800, 256)
# episode 14585 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 169.8
# (601, 32, 42, 1) (601, 256)
# episode 14586 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 166.8
# (588, 32, 42, 1) (588, 256)
# episode 14587 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 162.2
# (523, 32, 42, 1) (523, 256)
# episode 14588 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 162.0
# (1331, 32, 42, 1) (1331, 256)
# episode 14589 of 100000 complete,  explore val = 0.01, episode reward = 725.0, ave reward = 161.2
# (563, 32, 42, 1) (563, 256)
# episode 14590 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 166.2
# (513, 32, 42, 1) (513, 256)
# episode 14591 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 164.8
# (927, 32, 42, 1) (927, 256)
# episode 14592 of 100000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 163.8
# (635, 32, 42, 1) (635, 256)
# episode 14593 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 168.0
# (578, 32, 42, 1) (578, 256)
# episode 14594 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 167.0
# (628, 32, 42, 1) (628, 256)
# episode 14595 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 166.5
# (1035, 32, 42, 1) (1035, 256)
# episode 14596 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 162.2
# (636, 32, 42, 1) (636, 256)
# episode 14597 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 163.0
# (751, 32, 42, 1) (751, 256)
# episode 14598 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 162.8
# (1079, 32, 42, 1) (1079, 256)
# episode 14599 of 100000 complete,  explore val = 0.01, episode reward = 775.0, ave reward = 162.0
# (877, 32, 42, 1) (877, 256)
# episode 14600 of 100000 complete,  explore val = 0.01, episode reward = 375.0, ave reward = 169.8
# (725, 32, 42, 1) (725, 256)
# episode 14601 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 172.8
# (816, 32, 42, 1) (816, 256)
# episode 14602 of 100000 complete,  explore val = 0.01, episode reward = 300.0, ave reward = 173.0
# (671, 32, 42, 1) (671, 256)
# episode 14603 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 173.5
# (608, 32, 42, 1) (608, 256)
# episode 14604 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 174.2
# (645, 32, 42, 1) (645, 256)
# episode 14605 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 173.0
# (651, 32, 42, 1) (651, 256)
# episode 14606 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 173.0
# (531, 32, 42, 1) (531, 256)
# episode 14607 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 172.5
# (833, 32, 42, 1) (833, 256)
# episode 14608 of 100000 complete,  explore val = 0.01, episode reward = 525.0, ave reward = 167.2
# (750, 32, 42, 1) (750, 256)
# episode 14609 of 100000 complete,  explore val = 0.01, episode reward = 475.0, ave reward = 172.0
# (806, 32, 42, 1) (806, 256)
# episode 14610 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 175.5
# (548, 32, 42, 1) (548, 256)
# episode 14611 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 176.0
# (600, 32, 42, 1) (600, 256)
# episode 14612 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 174.0
# (817, 32, 42, 1) (817, 256)
# episode 14613 of 100000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 174.5
# (606, 32, 42, 1) (606, 256)
# episode 14614 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 176.2
# (723, 32, 42, 1) (723, 256)
# episode 14615 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 172.0
# (710, 32, 42, 1) (710, 256)
# episode 14616 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 173.5
# (751, 32, 42, 1) (751, 256)
# episode 14617 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 175.2
# (616, 32, 42, 1) (616, 256)
# episode 14618 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 176.2
# (640, 32, 42, 1) (640, 256)
# episode 14619 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 175.5
# (658, 32, 42, 1) (658, 256)
# episode 14620 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 174.8
# (621, 32, 42, 1) (621, 256)
# episode 14621 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 175.0
# (643, 32, 42, 1) (643, 256)
# episode 14622 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 173.0
# (610, 32, 42, 1) (610, 256)
# episode 14623 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 172.2
# (587, 32, 42, 1) (587, 256)
# episode 14624 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 171.2
# (654, 32, 42, 1) (654, 256)
# episode 14625 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 166.0
# (518, 32, 42, 1) (518, 256)
# episode 14626 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 166.2
# (834, 32, 42, 1) (834, 256)
# episode 14627 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 165.8
# (563, 32, 42, 1) (563, 256)
# episode 14628 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 167.5
# (811, 32, 42, 1) (811, 256)
# episode 14629 of 100000 complete,  explore val = 0.01, episode reward = 275.0, ave reward = 165.8
# (503, 32, 42, 1) (503, 256)
# episode 14630 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 167.2
# (637, 32, 42, 1) (637, 256)
# episode 14631 of 100000 complete,  explore val = 0.01, episode reward = 375.0, ave reward = 165.8
# (696, 32, 42, 1) (696, 256)
# episode 14632 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 169.0
# (670, 32, 42, 1) (670, 256)
# episode 14633 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 166.8
# (1996, 32, 42, 1) (1996, 256)
# episode 14634 of 100000 complete,  explore val = 0.01, episode reward = 300.0, ave reward = 167.8
# (588, 32, 42, 1) (588, 256)
# episode 14635 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 170.0
# (860, 32, 42, 1) (860, 256)
# episode 14636 of 100000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 170.0
# (823, 32, 42, 1) (823, 256)
# episode 14637 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 172.0
# (566, 32, 42, 1) (566, 256)
# episode 14638 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 171.2
# (797, 32, 42, 1) (797, 256)
# episode 14639 of 100000 complete,  explore val = 0.01, episode reward = 275.0, ave reward = 171.0
# (782, 32, 42, 1) (782, 256)
# episode 14640 of 100000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 168.5
# (597, 32, 42, 1) (597, 256)
# episode 14641 of 100000 complete,  explore val = 0.01, episode reward = 275.0, ave reward = 168.8
# (675, 32, 42, 1) (675, 256)
# episode 14642 of 100000 complete,  explore val = 0.01, episode reward = 225.0, ave reward = 169.5
# (633, 32, 42, 1) (633, 256)
# episode 14643 of 100000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 170.0
# (708, 32, 42, 1) (708, 256)
# episode 14644 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 170.5
# (596, 32, 42, 1) (596, 256)
# episode 14645 of 100000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 167.2
# (678, 32, 42, 1) (678, 256)
# episode 14646 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 163.8
# (506, 32, 42, 1) (506, 256)
# episode 14647 of 100000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 161.0
# (580, 32, 42, 1) (580, 256)
# episode 14648 of 100000 complete,  explore val = 0.01, episode reward = 0.0, ave reward = 158.8
# (650, 32, 42, 1) (650, 256)
# episode 14649 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 158.0
# (698, 32, 42, 1) (698, 256)
# episode 14650 of 100000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 157.8
# (695, 32, 42, 1) (695, 256)
# episode 14651 of 100000 complete,  explore val = 0.01, episode reward = 225.0, ave reward = 159.2
# (580, 32, 42, 1) (580, 256)
# episode 14652 of 100000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 159.8
# (791, 32, 42, 1) (791, 256)
# episode 14653 of 100000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 160.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cf8c7d3d2c01> in <module>
# ----> 1 demo.train()
#
# <ipython-input-1-312fae369c6d> in train(self, **kwargs)
#     317             # update Q function
#     318             if np.mod(n,self.episode_update) == 0:
# --> 319                 self.update_Q()
#     320
#     321             # update episode reward greater than exit_level, add to counter
#
# <ipython-input-1-312fae369c6d> in update_Q(self)
#     213
#     214                 # clamp all other models to their current values for this input/output pair
# --> 215                 q_update = self.Q(resizeImageMultiple(state)).flatten()
#     216                 q_update[action] = q
#     217                 q_vals.append(q_update)
#
# ~\.conda\envs\gym\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\.conda\envs\gym\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\.conda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\.conda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\.conda\envs\gym\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname,window_length = exit_window)
